# %%
! pip install llama-cpp-python requests tdqm
# Out:
# Collecting llama-cpp-python
#   Using cached llama_cpp_python-0.3.16-cp313-cp313-linux_x86_64.whl
# Requirement already satisfied: requests in ./venv/lib/python3.13/site-packages (2.32.5)
# Collecting tdqm
#   Using cached tdqm-0.0.1-py3-none-any.whl
# Requirement already satisfied: typing-extensions>=4.5.0 in ./venv/lib/python3.13/site-packages (from llama-cpp-python) (4.15.0)
# Collecting numpy>=1.20.0 (from llama-cpp-python)
#   Using cached numpy-2.4.2-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting diskcache>=5.6.1 (from llama-cpp-python)
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: jinja2>=2.11.3 in ./venv/lib/python3.13/site-packages (from llama-cpp-python) (3.1.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.13/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.13/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.13/site-packages (from requests) (2026.2.25)
# Collecting tqdm (from tdqm)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.13/site-packages (from jinja2>=2.11.3->llama-cpp-python) (3.0.3)
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Using cached numpy-2.4.2-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, numpy, diskcache, tdqm, llama-cpp-python
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [llama-cpp-python]4/5 [llama-cpp-python]
# Successfully installed diskcache-5.6.3 llama-cpp-python-0.3.16 numpy-2.4.2 tdqm-0.0.1 tqdm-4.67.3

# %%
import requests
from tqdm import tqdm
import os

# Mistral-7B-Instruct-v0.2 Model
# url = "https://huggingface.co/TheBloke/Mistral-7B-Instruct-v0.2-GGUF/resolve/main/mistral-7b-instruct-v0.2.Q4_K_M.gguf"
# filename = "mistral-7b-instruct-v0.2.Q4_K_M.gguf"

# print(f"Downloading {filename}...")


# response = requests.get(url, stream=True)
# total_size = int(response.headers.get('content-length', 0))

# with open(filename, 'wb') as file, tqdm(
#         desc=filename,
#         total=total_size,
#         unit='iB',
#         unit_scale=True,
#         unit_divisor=1024,
#     ) as bar:
#     for data in response.iter_content(chunk_size=1024):
#         bar.update(len(data))
#         file.write(data)

# print(f"Download complete! File: {filename}")
# print(f"File saved to: {os.path.abspath(filename)}")

# %%
import time
from llama_cpp import Llama

# ------------------------------------------------------------------
# Load the model
# ------------------------------------------------------------------
print("Loading Mistral model…")
start = time.time()

llm = Llama(
    model_path="mistral-7b-instruct-v0.2.Q4_K_M.gguf",
    n_ctx=32768,          # 32 k token context
    n_threads=None,       # auto‑detect CPU cores
    verbose=False
)

print(f"Model loaded in {time.time() - start:.2f}s")

# ------------------------------------------------------------------
# Query the model
# ------------------------------------------------------------------
response = llm.create_chat_completion(
    messages=[{
        "role": "user",
        "content": "What is pokemon go and why is it so uch fun. "
    }],
    max_tokens=200,
    temperature=0.7
)

print(response["choices"][0]["message"]["content"])
# Out:
# Loading Mistral model…
# Model loaded in 6.78s
#  Pokémon GO is a free-to-play location-based augmented reality (AR) mobile game developed by Niantic and published by The Pokémon Company. It was released in July 2016 and is based on the Pokémon franchise. In the game, players use their smartphones to navigate the real world to find, catch, train, and battle virtual Pokémon.
#
# The game uses real-world locations, such as parks, streets, and landmarks, as the backdrop for its virtual world. Players can collect various types of Pokémon by going to these locations and using virtual Pokéballs to catch them. The game also includes features like Gyms and PokéStops, which are located at real-world places and allow players to engage with other trainers and collect items.
#
# The game's use of AR technology creates an immersive experience that makes the world of Pokémon feel more real
